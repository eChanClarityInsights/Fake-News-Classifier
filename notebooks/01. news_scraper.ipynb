# %%
import feedparser as fp
import json
import newspaper
from newspaper import Article
from time import mktime
from datetime import datetime

# %%
# Set the limit for number of articles to download
LIMIT = 50

# %%
data = {}
data['newspapers'] = {}

# %%
# Loads the JSON files with news sites
with open('NewsPapers.json') as data_file:
    companies = json.load(data_file)

# %%
count = 1

# Iterate through each news company
# the company is the name, the value is the dictionary of links
for company, value in companies.items():
    # If a RSS link is provided in the JSON file, this will be the first choice.
    # Reason for this is that, RSS feeds often give more consistent and correct data.
    # If you do not want to scrape from the RSS-feed, just leave the RSS attr empty in the JSON file.
    if 'rss' in value:
        d = fp.parse(value['rss'])
        print("Downloading articles from ", company)
        newsPaper = {
            "rss": value['rss'],
            "link": value['link'],
            "articles": []
        }
        for entry in d.entries:
            # Check if publish date is provided, if no the article is skipped.
            # This is done to keep consistency in the data and to keep the script from crashing.
            if hasattr(entry, 'published'):
                if count > LIMIT:
                    break
                article = {}
                article['link'] = entry.link
                date = entry.published_parsed
                article['published'] = datetime.fromtimestamp(mktime(date)).isoformat()
                try:
                    content = Article(entry.link)
                    content.download()
                    content.parse()
                except Exception as e:
                    # If the download for some reason fails (ex. 404) the script will continue downloading
                    # the next article.
                    print(e)
                    print("continuing...")
                    continue
                article['title'] = content.title
                article['text'] = content.text
                article['author'] = content.authors
                newsPaper['articles'].append(article)
                if count % 10 == 0:
                    print(count, "articles downloaded from", company, ", url: ", entry.link)
                count = count + 1
    else:
        # This is the fallback method if a RSS-feed link is not provided.
        # It uses the python newspaper library to extract articles
        print("Building site for ", company)
        paper = newspaper.build(value['link'], memoize_articles=False)
        newsPaper = {
            "link": value['link'],
            "articles": []
        }
        noneTypeCount = 0
        for content in paper.articles:
            if count > LIMIT:
                break
            try:
                content.download()
                content.parse()
            except Exception as e:
                print(e)
                print("continuing...")
                continue
            # Again, for consistency, if there is no found publish date the article will be skipped.
            # After 10 downloaded articles from the same newspaper without publish date, the company will be skipped.
            if content.publish_date is None:
                print(count, " Article has date of type None...")
                noneTypeCount = noneTypeCount + 1
                if noneTypeCount > 10:
                    print("Too many noneType dates, aborting...")
                    noneTypeCount = 0
                    break
                count = count + 1
                continue
            article = {}
            article['title'] = content.title
            article['text'] = content.text
            article['link'] = content.url
            article['published'] = content.publish_date.isoformat()
            article['author'] = content.authors
            newsPaper['articles'].append(article)
            if count % 10 == 0: 
                print(count, "articles downloaded from", company, " using newspaper, url: ", content.url)
            count = count + 1
            noneTypeCount = 0
    count = 1
    data['newspapers'][company] = newsPaper


# Finally it saves the articles as a JSON-file.
try:
    fname = 'scraped_articles.json'
    print('saving articles . . . in {}'.format(fname))
    with open(fname, 'w') as outfile:
        json.dump(data, outfile)
except Exception as e: print(e)
# Out:
# Downloading articles from  newyorktimes_business
# 10 articles downloaded from newyorktimes_business , url:  https://www.nytimes.com/2018/03/23/business/trump-recession-forecast.html?partner=rss&emc=rss
# 20 articles downloaded from newyorktimes_business , url:  https://www.nytimes.com/video/business/100000005788184/what-bananas-tell-us-about-trade-wars.html?partner=rss&emc=rss
# 30 articles downloaded from newyorktimes_business , url:  https://www.nytimes.com/2018/03/23/obituaries/h-wayne-huizenga-entrepreneur-and-team-owner-is-dead-at-80.html?partner=rss&emc=rss
# 40 articles downloaded from newyorktimes_business , url:  https://www.nytimes.com/2018/03/23/travel/changes-at-the-airport.html?partner=rss&emc=rss
# Downloading articles from  newyorktimes_science
# 10 articles downloaded from newyorktimes_science , url:  https://www.nytimes.com/2018/03/23/health/right-to-try-drugs-fda.html?partner=rss&emc=rss
# 20 articles downloaded from newyorktimes_science , url:  https://www.nytimes.com/2018/03/21/health/breast-implants-lymphoma.html?partner=rss&emc=rss
# 30 articles downloaded from newyorktimes_science , url:  https://www.nytimes.com/2018/03/20/science/robert-langlands-abel-prize-mathematics.html?partner=rss&emc=rss
# Downloading articles from  newyorktimes_technology
# 10 articles downloaded from newyorktimes_technology , url:  https://www.nytimes.com/2018/03/23/business/craigslist-personals-trafficking-bill.html?partner=rss&emc=rss
# 20 articles downloaded from newyorktimes_technology , url:  https://www.nytimes.com/2018/03/22/business/youtube-gun-ban.html?partner=rss&emc=rss
# 30 articles downloaded from newyorktimes_technology , url:  https://www.nytimes.com/2018/03/21/science/robot-fish.html?partner=rss&emc=rss
# 40 articles downloaded from newyorktimes_technology , url:  https://www.nytimes.com/2018/03/20/technology/att-time-warner-trial-explained.html?partner=rss&emc=rss
# Downloading articles from  cnnmoney
# 10 articles downloaded from cnnmoney , url:  http://rss.cnn.com/~r/rss/money_latest/~3/d6yq7VoFs6E/index.html
# 20 articles downloaded from cnnmoney , url:  http://rss.cnn.com/~r/rss/money_latest/~3/Nl6u97N6eWc/index.html
# Downloading articles from  marketwatch_newsletters
# Downloading articles from  marketwatch_stories
# 10 articles downloaded from marketwatch_stories , url:  http://www.marketwatch.com/news/story.asp?guid=%7B682F3E58-2ED2-11E8-8EF2-AD271E51B38B%7D&siteid=rss&rss=1
# Downloading articles from  cnbc_top_news
# 10 articles downloaded from cnbc_top_news , url:  https://www.cnbc.com/2018/03/25/apple-music-jimmy-iovine-says-streaming-services-need-to-diversify.html
# 20 articles downloaded from cnbc_top_news , url:  https://www.cnbc.com/2018/03/24/model-chrissy-teigen-tells-followers-she-will-stop-using-snapchat.html
# 30 articles downloaded from cnbc_top_news , url:  https://www.cnbc.com/2018/03/23/rural-hospital-closures-force-towns-to-take-action.html
# Downloading articles from  cnbc_investing
# 10 articles downloaded from cnbc_investing , url:  https://www.cnbc.com/2018/03/23/market-retest-of-february-correction-is-actually-a-positive-analyst.html
# 20 articles downloaded from cnbc_investing , url:  https://www.cnbc.com/2018/03/22/the-market-is-having-a-hard-time-adjusting-to-a-new-day-at-the-fed.html
# 30 articles downloaded from cnbc_investing , url:  https://www.cnbc.com/2018/03/22/geopolitics-five-biggest-global-risks-of-2018.html
# Downloading articles from  marketwatch
# 10 articles downloaded from marketwatch , url:  https://www.theguardian.com/us-news/2018/mar/25/march-for-our-lives-parkland-students-excoriate-nra-politicians
# 20 articles downloaded from marketwatch , url:  https://www.theguardian.com/commentisfree/2018/mar/25/jeremy-corbyn-regret-antisemitic-incidents-jews
# 30 articles downloaded from marketwatch , url:  https://www.theguardian.com/football/2018/mar/25/steven-reid-roy-hodgson-crystal-palace-first-team-coach-republic-of-ireland
# 40 articles downloaded from marketwatch , url:  https://www.theguardian.com/sport/video/2018/mar/12/falling-and-rising-a-tale-of-two-jockeys-video
# 50 articles downloaded from marketwatch , url:  https://www.theguardian.com/lifeandstyle/2018/mar/25/nigel-slater-butternut-squash-recipes
# Downloading articles from  fox_business_latest_headlines
# 10 articles downloaded from fox_business_latest_headlines , url:  http://www.foxnews.com/us/2018/03/25/maryland-woman-charged-with-killing-her-great-grandmother.html
# Downloading articles from  fox_business_opinion
# 10 articles downloaded from fox_business_opinion , url:  http://feeds.foxnews.com/~r/foxnews/opinion/~3/ByguPdZqQGU/ivanka-trump-skill-based-education-is-crucial-to-putting-more-americans-on-path-to-promising-careers.html
# Downloading articles from  entrepreneur_latest
# 10 articles downloaded from entrepreneur_latest , url:  http://feedproxy.google.com/~r/entrepreneur/latest/~3/VxfI-hzhda8/310875
# Downloading articles from  entrepreneur_marketing
# 10 articles downloaded from entrepreneur_marketing , url:  http://feedproxy.google.com/~r/entrepreneur/salesandmarketing/~3/T1uFYRLVRjk/309343
# Downloading articles from  reuters_money
# 10 articles downloaded from reuters_money , url:  http://feeds.reuters.com/~r/news/wealth/~3/4B4Sg1izyZc/more-hedge-funds-closed-than-started-globally-in-2017-idUSKBN1GZ33B
# Downloading articles from  reuters_science
# 10 articles downloaded from reuters_science , url:  http://feeds.reuters.com/~r/reuters/scienceNews/~3/JjkCz5QNock/celebrated-dino-bird-archaeopteryx-could-fly-but-not-very-well-idUSKCN1GP2RA
# Downloading articles from  sciencedaily
# 10 articles downloaded from sciencedaily , url:  https://www.sciencedaily.com/releases/2018/03/180323132704.htm
# 20 articles downloaded from sciencedaily , url:  https://www.sciencedaily.com/releases/2018/03/180323104841.htm
# 30 articles downloaded from sciencedaily , url:  https://www.sciencedaily.com/releases/2018/03/180323104808.htm
# 40 articles downloaded from sciencedaily , url:  https://www.sciencedaily.com/releases/2018/03/180323090853.htm
# 50 articles downloaded from sciencedaily , url:  https://www.sciencedaily.com/releases/2018/03/180322181335.htm
# Downloading articles from  economist_business
# 10 articles downloaded from economist_business , url:  https://www.economist.com/news/business/21739179-americas-pharmaceutical-giants-may-also-need-rethink-their-business-model-fda-wants-help?fsrc=rss
# Downloading articles from  economist_science_and_tech
# You must `download()` an article first!
#
# continuing...
# You must `download()` an article first!
#
# continuing...
# 10 articles downloaded from economist_science_and_tech , url:  https://www.economist.com/news/science-and-technology/21738869-taking-care-bumps-and-potholes-new-type-smooth-car-suspension?fsrc=rss
# Downloading articles from  fivethirtyeight_science
# 10 articles downloaded from fivethirtyeight_science , url:  https://fivethirtyeight.com/features/its-one-thing-for-trump-to-like-uranium-its-another-for-him-to-save-it/
# 20 articles downloaded from fivethirtyeight_science , url:  https://fivethirtyeight.com/features/tom-brady-is-drowning-in-his-own-junk-science-advice/
# Downloading articles from  fivethirtyeight_economics
# 10 articles downloaded from fivethirtyeight_economics , url:  https://fivethirtyeight.com/features/could-the-supreme-court-really-bust-public-sector-unions/
# 20 articles downloaded from fivethirtyeight_economics , url:  https://fivethirtyeight.com/features/legal-weed-isnt-the-boon-small-businesses-thought-it-would-be/
# Downloading articles from  nbpostgazette
# 10 articles downloaded from nbpostgazette , url:  http://nbpostgazette.com/2018/03/23/growing-opportunity-for-startups-in-the-premium-wireless-routers-industry/
# Downloading articles from  journalismday
# 10 articles downloaded from journalismday , url:  http://journalismday.com/2018/03/global-vertical-turbine-pumps-market-growth-outlook-by-2023-xylem/
# Downloading articles from  satprnews
# 10 articles downloaded from satprnews , url:  https://www.satprnews.com/2018/03/25/server-virtualization-market-expansion-to-be-persistent-during-2017-2025-2/
# 20 articles downloaded from satprnews , url:  https://www.satprnews.com/2018/03/25/increasing-rd-efforts-and-innovation-to-propel-the-expansion-of-virtual-networking-market/
# 30 articles downloaded from satprnews , url:  https://www.satprnews.com/2018/03/25/pigment-intermediate-market-opportunities-and-forecasts-2017-2025/
# 40 articles downloaded from satprnews , url:  https://www.satprnews.com/2018/03/25/pharmaceutical-solvent-market-will-reach-at-a-cagr-of-4-2-from-2016-2026/
# 50 articles downloaded from satprnews , url:  https://www.satprnews.com/2018/03/25/3-2-cagr-anticipated-for-bulk-terminals-market-during-2016-2026/
# Downloading articles from  insidertradings
# 10 articles downloaded from insidertradings , url:  https://www.insidertradings.org/global-and-chinese-motorized-positioners-for-robots-industry-2018-market-research-report/
# Downloading articles from  truthfulreporter
# Downloading articles from  highlandmirror
# 10 articles downloaded from highlandmirror , url:  https://www.highlandmirror.com/2018-03-20-global-ftir-spectrometer-market-2018-new-era-of-industry-swot-analysis-business-overview-and-forecast-2025
# You must `download()` an article first!
#
# continuing...
# 20 articles downloaded from highlandmirror , url:  https://www.highlandmirror.com/2018-03-20-global-diabetic-shoes-sales-market-2018-2023
# 30 articles downloaded from highlandmirror , url:  https://www.highlandmirror.com/2018-03-20-global-breast-imaging-technologies-market-2018-2023
# 40 articles downloaded from highlandmirror , url:  https://www.highlandmirror.com/2018-03-20-global-wireless-gas-detector-market-2018-2023
# 50 articles downloaded from highlandmirror , url:  https://www.highlandmirror.com/2018-03-20-global-exercise-bikes-market-2018-2025
# Downloading articles from  thefinancialanalyst
# Downloading articles from  reportagestuff
# 10 articles downloaded from reportagestuff , url:  http://reportagestuff.com/2018/03/25/global-transformer-monitoring-system-market-trends-2018-siemens/
# Downloading articles from  tokenfolks
# You must `download()` an article first!
#
# continuing...
# You must `download()` an article first!
#
# continuing...
# Downloading articles from  heraldanalyst
# 10 articles downloaded from heraldanalyst , url:  https://heraldanalyst.com/global-pancreatitis-drugs-market-2018-gsk-abbvie-inc-medinova-mochida-vital-nutrients-chiesi/
# Downloading articles from  findmarketresearch
# 10 articles downloaded from findmarketresearch , url:  https://heraldanalyst.com/global-pancreatitis-drugs-market-2018-gsk-abbvie-inc-medinova-mochida-vital-nutrients-chiesi/
# saving articles . . . in scraped_articles_test.json
